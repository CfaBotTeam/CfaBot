# %%
import xml.etree.ElementTree as ET
from xml.etree.ElementTree import ParseError
import pandas as pd
from glob import glob
import os.path as op


def add_records(path, all_records):
    xml_data = open(path).read()
    xml_data = "<problems>" + xml_data + "</problems>"
    problems = ET.XML(xml_data)
    for problem in problems:
        record = {}
        for child in problem:
            if child.tag == "choices":
                for choice in child:
                    id = choice.attrib['id']
                    record[choice.tag + '_' + id] = choice.text
            else:
                record[child.tag] = child.text
        all_records.append(record)


all_records = []
file_paths = sorted(glob(op.join('Data', 'qa_mock_exams', '*', '*.xml')))
for path in file_paths:
    try:
        add_records(path, all_records)
    except ParseError as e:
        print("Exception in file '{}': {}".format(path, e))

problems_df = pd.DataFrame(all_records)

# %%
problems_df
# Out:
#      answer                                           choice_A  \
# 0         A              rely on the integrity of input data.
# 1         B       disclosing potential conflicts of interest.
# 2         B                                               No.
# 3         C                             suspend the employee.
# 4         D                                             No No
# 5         C                                             No No
# 6         A                                             No No
# 7         D                                             No No
# 8         A                                          clients.
# 9         B                                               No.
# 10        D                                               No.
# 11        A                                               No.
# 12        C                                               No.
# 13        C                                               No.
# 14        C                                               No.
# 15        C                                    tip the media.
# 16        A                                               No.
# 17        B                                               No.
# 18        C                                        liquidity.
# 19        C                                         $320,000.
# 20        B                                        ($24,537.)
# 21        B                                            12.5%.
# 22        D                                           Answer A
# 23        B                                           Answer A
# 24        A                                        6.83% 77.5
# 25        A                                         1.36 0.52
# 26        D                                         a priori.
# 27        D              product of the variables' variances.
# 28        A        has a finite number of specified outcomes.
# 29        C                                     15.0 to 69.0.
# ...     ...                                                ...
# 1384      A                                              swap.
# 1385      C                     pay EUR 687,500 to the dealer.
# 1386      A                                              $200.
# 1387      C                                                No.
# 1388      B                                     USD 1,750,000.
# 1389      C                       sell calls on shares of ABC.
# 1390      C                                       is callable.
# 1391      A      assumes all yields change by the same amount.
# 1392      B       Both investors will choose the taxable bond.
# 1393      A                                         spot rate.
# 1394      A                                          increase.
# 1395      A                                           $122.74.
# 1396      B                               yield curve is flat.
# 1397      B                                             0.74%.
# 1398      A                    increases measurement accuracy.
# 1399      B                                              1.85.
# 1400      B                                     put the issue.
# 1401      B                                          $124,000.
# 1402      A                                        hedge fund.
# 1403      B                                      price return.
# 1404      C                                      increase risk
# 1405      C                   assets are not marked to market.
# 1406      A                     Real estate investment trusts.
# 1407      A                                            10.89%.
# 1408      A                                  Insurance company
# 1409      C                                             17.9%.
# 1410      B                                             6.45%.
# 1411      B                                              1.02.
# 1412      C                                          M-squared
# 1413      C  low ability to take risk, but a high willingne...
#
#                                                choice_B  \
# 0     address every aspect of performance measurement.
# 1     habitually voting with management on proxies t...
# 2     Yes, because she has breached her duty to her ...
# 3        suspend Marshall from her supervisory duties.
# 4                                               No Yes
# 5                                               No Yes
# 6                                               No Yes
# 7                                               No Yes
# 8                                          colleagues.
# 9     Yes, because he failed to obtain consent from ...
# 10    Yes, because the performance should be stated ...
# 11    Yes, because he has a duty of loyalty to his e...
# 12        Yes, with respect to client confidentiality.
# 13                   Yes, with respect to suitability.
# 14                   Yes, with respect to suitability.
# 15                                alert CFA Institute.
# 16                       Yes, with respect to loyalty.
# 17          Yes, with respect to conflict of interest.
# 18                                           maturity.
# 19                                           $423,000.
# 20                                            $10,558.
# 21                                              20.8%.
# 22                                            Answer B
# 23                                            Answer B
# 24                                          6.83% 96.8
# 25                                           1.36 7.44
# 26                                          objective.
# 27                 variance of the dependent variable.
# 28          is based on the Bernoulli random variable.
# 29                                       18.8 to 65.2.
# ...                                                 ...
# 1384                                  futures contract.
# 1385             receive EUR 4,312,500 from the dealer.
# 1386                                              $280.
# 1387             Yes, if its time value is high enough.
# 1388                                     EUR 1,125,000.
# 1389                                               None
# 1390                                 is a step-up note.
# 1391  assumes all the bonds have the same discount r...
# 1392    Both investors will choose the tax-exempt bond.
# 1393                                      yield spread.
# 1394                                          decrease.
# 1395                                           $130.04.
# 1396                              yield curve is steep.
# 1397                                             1.48%.
# 1398         is easier to model than scenario analysis.
# 1399                                              3.09.
# 1400                                    call the issue.
# 1401                                          $322,600.
# 1402                              venture capital fund.
# 1403                                  collateral yield.
# 1404                                    enhance return.
# 1405             data are subject to survivorship bias.
# 1406                  Real estate limited partnerships.
# 1407                                            11.06%.
# 1408                              Charitable foundation
# 1409                                             27.6%.
# 1410                                             7.90%.
# 1411                                              1.05.
# 1412                                       Sharpe ratio
# 1413  high ability to take risk, but a low willingne...
#
#                                                choice_C  \
# 0     consist of required provisions for firms to fo...
# 1     disclosing confidential client information to ...
# 2     Yes, because she has failed to obtain written ...
# 3     initiate an investigation to determine the ext...
# 4                                               Yes No
# 5                                               Yes No
# 6                                               Yes No
# 7                                               Yes No
# 8                                      his reputation.
# 9     Yes, because he failed to disclose his new emp...
# 10    Yes, because the returns must include terminat...
# 11    Yes, because bankruptcy represents a potential...
# 12    Yes, with respect to diligence and reasonable ...
# 13                  Yes, with respect to fair dealing.
# 14                  Yes, with respect to fair dealing.
# 15                            consult outside counsel.
# 16       Yes, with respect to disclosure of conflicts.
# 17       Yes, with respect to additional compensation.
# 18                                       default risk.
# 19                                         $1,176,000.
# 20                                            $49,825.
# 21                                              25.0%.
# 22                                            Answer C
# 23                                            Answer C
# 24                                          7.68% 77.5
# 25                                           1.53 0.52
# 26                                          empirical.
# 27               variance of the independent variable.
# 28     is approximated by the log-normal distribution.
# 29                                       34.3 to 49.7.
# ...                                                 ...
# 1384                                  forward contract.
# 1385             receive EUR 5,000,000 from the dealer.
# 1386                                              $320.
# 1387            Yes, if it pays a high enough dividend.
# 1388                                     EUR 1,250,000.
# 1389  sell calls on shares of ABC. B. sell puts on s...
# 1390                      has a sinking fund provision.
# 1391  ignores differences in coupon rates across the...
# 1392  Investor A will choose the tax-exempt bond and...
# 1393                                      forward rate.
# 1394                                     stay the same.
# 1395                                           $192.86.
# 1396  security has a bullet maturity rather than an ...
# 1397                                             2.06%.
# 1398  requires the yield curve to change in a parall...
# 1399                                              6.17.
# 1400                                 convert the issue.
# 1401                                          $645,200.
# 1402                  leveraged buyout fund. Answer = A
# 1403                                 convenience yield.
# 1404                      reduce exposure to inflation.
# 1405  indices are constructed using futures contract...
# 1406  Commercial mortgage backed securities. Answer = A
# 1407                                 12.29%. Answer = A
# 1408                       Defined benefit pension plan
# 1409                                             35.2%.
# 1410                                             9.13%.
# 1411                                               1.16
# 1412                                      Treynor ratio
# 1413  high ability to take risk and a high willingne...
#
#                                                choice_D  \
# 0     must be applied with the goal of achieving exc...
# 1     using client brokerage to purchase goods or se...
# 2     Yes, because her allocation procedures contrib...
# 3     demand that the employee involved provide assu...
# 4     Yes Yes  Select exactly 1 answer(s) from the f...
# 5     Yes Yes  Select exactly 1 answer(s) from the f...
# 6     Yes Yes  Select exactly 1 answer(s) from the f...
# 7     Yes Yes  Select exactly 1 answer(s) from the f...
# 8                           the employer's reputation.
# 9     Yes, because he violated his duty to his emplo...
# 10    Yes, because the presentation makes assurances...
# 11    Yes, because bankruptcy reflects poorly on his...
# 12    Yes, with respect to material nonpublic inform...
# 13       Yes, with respect to priority of transaction.
# 14    Yes, with respect to diligence and a reasonabl...
# 15                      notify regulatory authorities.
# 16       Yes, with respect to additional compensation.
# 17    Yes, with respect to responsibilities of super...
# 18                                      business risk.
# 19                                         $1,552,000.
# 20                                            $93,929.
# 21                                              41.7%.
# 22                                            Answer D
# 23                                            Answer D
# 24    7.68% 96.8                  Select exactly 1 a...
# 25    1.53 7.44                    Select exactly 1 ...
# 26                                         subjective.
# 27      product of the variables' standard deviations.
# 28     has an infinite number of unspecified outcomes.
# 29                                       39.0 to 45.0.
# ...                                                 ...
# 1384                                                NaN
# 1385                                                NaN
# 1386                                                NaN
# 1387                                                NaN
# 1388                                                NaN
# 1389                                                NaN
# 1390                                                NaN
# 1391                                                NaN
# 1392                                                NaN
# 1393                                                NaN
# 1394                                                NaN
# 1395                                                NaN
# 1396                                                NaN
# 1397                                                NaN
# 1398                                                NaN
# 1399                                                NaN
# 1400                                                NaN
# 1401                                                NaN
# 1402                                               None
# 1403                                                NaN
# 1404                                                NaN
# 1405                                               None
# 1406                                               None
# 1407                                               None
# 1408                                                NaN
# 1409                                                NaN
# 1410                                                NaN
# 1411                                                NaN
# 1412                                                NaN
# 1413                                                NaN
#
#                                                comments  \
# 0     Global Investment Performance Standards (GIPS)...
# 1     Guidance for Standards I-VII, Standards of Pra...
# 2     Guidance for Standards I-VII, Standards of Pra...
# 3     Guidance for Standards I-VII, Standards of Pra...
# 4     Guidance for Standards I-VII, Standards of Pra...
# 5     Guidance for Standards I-VII, Standards of Pra...
# 6     Guidance for Standards I-VII, Standards of Pra...
# 7     Guidance for Standards I-VII, Standards of Pra...
# 8     Guidance for Standards I-VII, Standards of Pra...
# 9     Standards of Practice Handbook, 9th edition (C...
# 10    Standards of Practice Handbook, 9th edition (C...
# 11    Standards of Practice Handbook, 9th edition (C...
# 12    Standards of Practice Handbook, 9th edition (C...
# 13    Standards of Practice Handbook, 9th edition (C...
# 14    Standards of Practice Handbook, 9th edition (C...
# 15    Standards of Practice Handbook, 9th edition (C...
# 16    Standards of Practice Handbook, 9th edition (C...
# 17    Standards of Practice Handbook, 9th edition (C...
# 18    "The Time Value of Money," Richard A. Defusco,...
# 19    "The Time Value of Money," Richard A. Defusco,...
# 20    "Discounted Cash Flow Applications," Richard A...
# 21    "Discounted Cash Flow Applications," Richard A...
# 22    "Discounted Cash Flow Applications," Richard A...
# 23    "Statistical Concepts and Market Returns," Ric...
# 24    "Statistical Concepts and Market Returns," Ric...
# 25    "Statistical Concepts and Market Returns," Ric...
# 26    "Probability Concepts," Richard A. Defusco, De...
# 27    "Probability Concepts," Richard A. Defusco, De...
# 28    "Common Probability Distributions," Richard A....
# 29    "Common Probability Distributions," Richard A....
# ...                                                 ...
# 1384  "Derivative Markets and Instruments," Don M. C...
# 1385  "Forward Markets and Contracts," Don M. Chance...
# 1386  "Futures Markets and Contracts," Don M. Chance...
# 1387  "Option Markets and Contracts," Don M. Chance,...
# 1388  "Swap Markets and Contracts," Don M. Chance, C...
# 1389  "Risk Management Applications of Option Strate...
# 1390  "Features of Debt Securities", Frank J. Fabozz...
# 1391  "Risks Associated with Investing in Bonds", Fr...
# 1392  "Understanding Yield Spreads", Frank J. Fabozz...
# 1393  "Understanding Yield Spreads", Frank J. Fabozz...
# 1394  "Introduction to the Valuation of Debt Securit...
# 1395  "Introduction to the Valuation of Debt Securit...
# 1396  "Yield Measures, Spot Rates, and Forward Rates...
# 1397  "Yield Measures, Spot Rates, and Forward Rates...
# 1398  "Introduction to the Measurement of Interest R...
# 1399  "Introduction to the Measurement of Interest R...
# 1400  "Features of Debt Securities," Frank J. Fabozz...
# 1401  "Risks Associated with Investing in Bonds," Fr...
# 1402  "Introduction to Alternative Investments," Ter...
# 1403  "Investing in Commodities," Ronald G. Layard-L...
# 1404  "Investing in Commodities," Ronald G. Layard-L...
# 1405  "Introduction to Alternative Investments," Ter...
# 1406  "Introduction to Alternative Investments," Ter...
# 1407  "Introduction to Alternative Investments," Ter...
# 1408  "Portfolio Management: An Overview" by Robert ...
# 1409  "Portfolio Risk and Return: Part I" by Vijay S...
# 1410  "Portfolio Risk and Return: Part I" by Vijay S...
# 1411  "Portfolio Risk and Return: Part II" by Vijay ...
# 1412  "Portfolio Risk and Return: Part II" by Vijay ...
# 1413  "Basics of Portfolio Planning and Construction...
#
#                                                question
# 0     1. Which of the following is a key characteris...
# 1     2. According to the Standards of Practice Hand...
# 2     3. Carla Scott, CFA, is a portfolio manager fo...
# 3     4. Kim Li, CFA, is a portfolio manager for an ...
# 4     5. Marcus Takeda, CFA, is an analyst at a smal...
# 5     6. David Gunard, CFA, is an equity analyst at ...
# 6     7. According to the Standards of Practice Hand...
# 7     8. According to the Standards of Practice Hand...
# 8     9. According to the Standards of Practice Hand...
# 9     10. Buta Singh, CFA, has a large extended fami...
# 10    11. Meryl Mamet, CFA, manages an emerging mark...
# 11    12. Crandall Temasek, CFA, filed for personal ...
# 12    13. Sallie Lewis, CFA, is a research analyst c...
# 13    14. Clive Bowers, CFA, is a portfolio manager ...
# 14    15. Narupa Rhasta, CFA, is manager of the fast...
# 15    16. Jimmy Lee, CFA, is an investment banker in...
# 16    17. Rene Whatcom, CFA, is an independent contr...
# 17    18. Angus Draper, CFA, is a senior portfolio m...
# 18    19. The yield to maturity on otherwise identic...
# 19    20. Rachel Kelly, age 24, is planning for reti...
# 20    21. An analyst gathered the following informat...
# 21    22. An analyst gathered the following informat...
# 22    23. A 270-day U.S. Treasury bill with a face v...
# 23    24. An analyst gathered the following informat...
# 24    25. An analyst gathered the following annual r...
# 25    26. An analyst gathered the following informat...
# 26    27. If an analyst estimates the probability of...
# 27    28. Which of the following statements regardin...
# 28    29. Which of the following best describes the ...
# 29    30. An analyst determined that the sample mean...
# ...                                                 ...
# 1384  91. A corporation issues 5-year fixed-rate bon...
# 1385  92. A portfolio manager is required to sell 31...
# 1386  93. A trader takes a long position in 40 futur...
# 1387  94. An investor is long an in-the-money Americ...
# 1388  95. A European company issues a 5-year euro-de...
# 1389  96. An investor with $5000 to invest believes ...
# 1390  97. If a bond's issuer is required to retire a...
# 1391  98. One reason why the duration of a portfolio...
# 1392  99. Investor A's marginal tax rate is 45%, whi...
# 1393  100. The yield on a U.S. Treasury STRIPS secur...
# 1394  101. Consider a 5-year option-free bond that i...
# 1395  102. The market value of an 18-year zero-coupo...
# 1396  103. All else equal, the difference between th...
# 1397  104. Assume the following six-month forward ra...
# 1398  105. One advantage of the full valuation appro...
# 1399  106. An analyst uses a valuation model to esti...
# 1400  107. Which of the following is least likely to...
# 1401  108. The bonds issued by ALS Corp. are current...
# 1402  109. An alternative investments fund that empl...
# 1403  110. If an investor uses derivatives to make a...
# 1404  111. The most likely impact of adding commodit...
# 1405  112. The return on a commodity index is likely...
# 1406  113. Which of the following investments most l...
# 1407  114. High Plains Capital is a hedge fund with ...
# 1408  115. Which of the following institutional inve...
# 1409  116. An asset management firm generated the fo...
# 1410  117. Consider a portfolio with two assets. Ass...
# 1411  118. An asset has an annual return of 19.9%, s...
# 1412  119. Which of the following performance measur...
# 1413  120. A financial advisor gathers the following...
#
# [1414 rows x 7 columns]
